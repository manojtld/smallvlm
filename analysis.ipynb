# %%
import json

# %%
res = json.load(open('evals/results/baseline_qwen35_08b.json'))

# %%
res
# Out:
# {'model': 'Qwen/Qwen3.5-0.8B',
#  'n_samples': 771,
#  'level1': {'accuracy': 0.3718,
#   'sensitivity': 0.9925,
#   'specificity': 0.0191,
#   'precision': 0.365,
#   'f1': 0.5337,
#   'tp': 265,
#   'tn': 9,
#   'fp': 461,
#   'fn': 2,
#   'n': 737},
#  'level2': {'per_label': {'Cardiomegaly': {'accuracy': 0.3333,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3333,
#     'f1': 0.5,
#     'tp': 4,
#     'tn': 0,
#     'fp': 8,
#     'fn': 0,
#     'n': 12},
#    'Pleural Effusion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Atelectasis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 11,
#     'fn': 0,
#     'n': 11},
#    'Opacity': {'accuracy': 0.3636,
#     'sensitivity': 1.0,
# ...
