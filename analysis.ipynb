# %%
import json

# %%
res = json.load(open('evals/results/baseline_qwen35_08b.json'))

# %%
res
# Out:
# {'model': 'Qwen/Qwen3.5-0.8B',
#  'n_samples': 771,
#  'level1': {'accuracy': 0.3718,
#   'sensitivity': 0.9925,
#   'specificity': 0.0191,
#   'precision': 0.365,
#   'f1': 0.5337,
#   'tp': 265,
#   'tn': 9,
#   'fp': 461,
#   'fn': 2,
#   'n': 737},
#  'level2': {'per_label': {'Cardiomegaly': {'accuracy': 0.3333,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3333,
#     'f1': 0.5,
#     'tp': 4,
#     'tn': 0,
#     'fp': 8,
#     'fn': 0,
#     'n': 12},
#    'Pleural Effusion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Atelectasis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 11,
#     'fn': 0,
#     'n': 11},
#    'Opacity': {'accuracy': 0.3636,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3636,
#     'f1': 0.5333,
#     'tp': 4,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Edema': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Congestion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Emphysema': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Nodule': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Infiltrate': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Airspace Disease': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 7},
#    'Calcinosis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Calcified Granuloma': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Fractures, Bone': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Catheters, Indwelling': {'accuracy': 0.1429,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.1429,
#     'f1': 0.25,
#     'tp': 1,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 7}},
#   'macro': {'macro_f1': 0.1274,
#    'macro_sensitivity': 0.4286,
#    'macro_specificity': 0.0,
#    'macro_precision': 0.0795}}}

# %%
import pandas as pd
traces = pd.read_json('evals/results/baseline_qwen35_08b.traces.jsonl', lines=True)

# %%
trace = traces['l2_raw'].tolist()

# %%
traces
# Out:
#    uid                                      frontal_image  gt_normal  \
# 0    4  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 1    9  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 2   21  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 3   29  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
#
#                                          gt_problems  l1_raw  l1_pred  \
# 0  [Pulmonary Disease, Chronic Obstructive, Bullo...  Normal     True
# 1                     [Calcified Granuloma, Density]  Normal     True
# 2  [Calcified Granuloma, Breast Implants, Deformity]  Normal     True
# 3  [Cardiomegaly, Diaphragm, Tube, Inserted, Airs...  Normal     True
#
#                                               l2_raw  \
# 0  ```json\n[\n\t{"r": "Cardiomegaly", "f": true}...
# 1  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 2  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 3  ```json\n[\n\t{"Finding Name": "Calcinosis", "...
#
#                                              l2_pred  \
# 0  {'Cardiomegaly': True, 'Pleural Effusion': Tru...
# 1  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 2  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 3  {'Cardiomegaly': None, 'Pleural Effusion': Non...
#
#                                               l3_raw  \
# 0  **Findings:** The heart is normal size and con...
# 1  **Findings:** The heart size is normal with an...
# 2  **Findings:** The heart size is normal with an...
# 3  **Findings:** The cardiac silhouette is enlarg...
#
#                                          l3_findings  \
# 0  The heart is normal size and contour with no c...
# 1  The heart size is normal with an unremarkable ...
# 2  The heart size is normal with an unremarkable ...
# 3  The cardiac silhouette is enlarged but within ...
#
#                                        l3_impression
# 0
# 1
# 2  Normal cardiopulmonary examination. Clear lung...
# 3  Cardiomegaly likely secondary to chronic heart...
