# %%
import json

# %%
res = json.load(open('evals/results/baseline_qwen35_08b.json'))

# %%
res
# Out:
# {'model': 'Qwen/Qwen3.5-0.8B',
#  'n_samples': 771,
#  'level1': {'accuracy': 0.3718,
#   'sensitivity': 0.9925,
#   'specificity': 0.0191,
#   'precision': 0.365,
#   'f1': 0.5337,
#   'tp': 265,
#   'tn': 9,
#   'fp': 461,
#   'fn': 2,
#   'n': 737},
#  'level2': {'per_label': {'Cardiomegaly': {'accuracy': 0.3333,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3333,
#     'f1': 0.5,
#     'tp': 4,
#     'tn': 0,
#     'fp': 8,
#     'fn': 0,
#     'n': 12},
#    'Pleural Effusion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Atelectasis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 11,
#     'fn': 0,
#     'n': 11},
#    'Opacity': {'accuracy': 0.3636,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3636,
#     'f1': 0.5333,
#     'tp': 4,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Edema': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Congestion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Emphysema': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Nodule': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Infiltrate': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Airspace Disease': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 7},
#    'Calcinosis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Calcified Granuloma': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Fractures, Bone': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Catheters, Indwelling': {'accuracy': 0.1429,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.1429,
#     'f1': 0.25,
#     'tp': 1,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 7}},
#   'macro': {'macro_f1': 0.1274,
#    'macro_sensitivity': 0.4286,
#    'macro_specificity': 0.0,
#    'macro_precision': 0.0795}}}

# %%
import pandas as pd
traces = pd.read_json('evals/results/baseline_qwen35_08b.traces.jsonl', lines=True)

# %%
traces
# Out:
#       uid                                      frontal_image  gt_normal  \
# 0       4  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 1       9  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 2      21  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 3      29  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 4      33  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# ..    ...                                                ...        ...
# 766  3971  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 767  3974  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 768  3978  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 769  3982  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 770  3989  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
#
#                                            gt_problems  l1_raw  l1_pred  \
# 0    [Pulmonary Disease, Chronic Obstructive, Bullo...  Normal      1.0
# 1                       [Calcified Granuloma, Density]  Normal      1.0
# 2    [Calcified Granuloma, Breast Implants, Deformity]  Normal      1.0
# 3    [Cardiomegaly, Diaphragm, Tube, Inserted, Airs...  Normal      1.0
# 4                               [Surgical Instruments]  Normal      1.0
# ..                                                 ...     ...      ...
# 766                                                 []  Normal      1.0
# 767  [Lung, Pulmonary Emphysema, Airspace Disease, ...  Normal      1.0
# 768                                                 []  Normal      1.0
# 769                                                 []  Normal      1.0
# 770                        [Diaphragmatic Eventration]  Normal      1.0
#
#                                                 l2_raw  \
# 0    ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 1    ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 2    ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 3    ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 4    ```json\n[\n  {\n    "Finding Name": "Pleural ...
# ..                                                 ...
# 766  ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 767  ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 768  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 769  ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 770  ```json\n[\n  {"Finding Name": "Pleural Effusi...
#
#                                                l2_pred  \
# 0    {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 1    {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 2    {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 3    {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 4    {'Cardiomegaly': None, 'Pleural Effusion': Non...
# ..                                                 ...
# 766  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 767  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 768  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 769  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 770  {'Cardiomegaly': None, 'Pleural Effusion': Non...
#
#                                                 l3_raw  \
# 0    **Findings:**\n*   Lungs appear hyperinflated ...
# 1    **Findings:** The lungs are clear without foca...
# 2    **Findings:** The cardiac silhouette is normal...
# 3    **Findings:**\nThe cardiac silhouette is enlar...
# 4    **Findings:** The lungs are clear without foca...
# ..                                                 ...
# 766  **Findings:**\nThe lungs are clear without foc...
# 767  **Findings:**\nThe cardiac silhouette is norma...
# 768  **Findings:** The cardiac silhouette is normal...
# 769  **Findings:** The lungs are clear without foca...
# 770  **Findings:** The lungs are clear without foca...
#
#                                            l3_findings  \
# 0    Lungs appear hyperinflated with flattened diap...
# 1    The lungs are clear without focal consolidatio...
# 2    The cardiac silhouette is normal size and cont...
# 3    The cardiac silhouette is enlarged, but evalua...
# 4    The lungs are clear without focal consolidatio...
# ..                                                 ...
# 766  The lungs are clear without focal consolidatio...
# 767  The cardiac silhouette is normal in size and c...
# 768  The cardiac silhouette is normal in size and c...
# 769  The lungs are clear without focal consolidatio...
# 770  The lungs are clear without focal consolidatio...
#
#                                          l3_impression
# 0    There is evidence of severe COPD/chronic lung ...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 766  No acute cardiopulmonary abnormality detected....
# 767  Diffuse bilateral parenchymal opacity involves...
# 768  Normal heart size and pulmonary vasculature. C...
# 769  Clear lungs with possible minor basal fibrosis...
# 770
#
# [771 rows x 11 columns]

# %%
trace = traces['l3_raw'].tolist()

# %%
from pprint import pprint

# %%
pprint(trace[10])
# Out:
# ('**Findings:** The lungs are clear without focal consolidation, pleural '
#  'effusion or pneumothorax. Cardiomediastinal and hilar contours are within '
#  'normal limits for size and configuration. Osseous structures appear intact '
#  'with no acute fracture identified; anterior cervical hardware is noted. No '
#  "pulmonary edema is present. Clinical correlation recommended given patient's "
#  'history of trauma to shoulder girdle (implied by "KAB" marker). \n'
#  '\n'
#  '*Impression:* Clear lung fields. Normal heart size and mediastinum. Cervical '
#  'spine instrumentation unchanged. Trauma site warrants further evaluation if '
#  'clinically indicated.')
