# %%
import json

# %%
res = json.load(open('evals/results/baseline_qwen35_08b.json'))

# %%
res
# Out:
# {'model': 'Qwen/Qwen3.5-0.8B',
#  'n_samples': 771,
#  'level1': {'accuracy': 0.3718,
#   'sensitivity': 0.9925,
#   'specificity': 0.0191,
#   'precision': 0.365,
#   'f1': 0.5337,
#   'tp': 265,
#   'tn': 9,
#   'fp': 461,
#   'fn': 2,
#   'n': 737},
#  'level2': {'per_label': {'Cardiomegaly': {'accuracy': 0.3333,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3333,
#     'f1': 0.5,
#     'tp': 4,
#     'tn': 0,
#     'fp': 8,
#     'fn': 0,
#     'n': 12},
#    'Pleural Effusion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Atelectasis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 11,
#     'fn': 0,
#     'n': 11},
#    'Opacity': {'accuracy': 0.3636,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.3636,
#     'f1': 0.5333,
#     'tp': 4,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Edema': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Pulmonary Congestion': {'accuracy': 0.0909,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.0909,
#     'f1': 0.1667,
#     'tp': 1,
#     'tn': 0,
#     'fp': 10,
#     'fn': 0,
#     'n': 11},
#    'Emphysema': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Nodule': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Infiltrate': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Airspace Disease': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 7,
#     'fn': 0,
#     'n': 7},
#    'Calcinosis': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Calcified Granuloma': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Fractures, Bone': {'accuracy': 0.0,
#     'sensitivity': 0.0,
#     'specificity': 0.0,
#     'precision': 0.0,
#     'f1': 0.0,
#     'tp': 0,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 6},
#    'Catheters, Indwelling': {'accuracy': 0.1429,
#     'sensitivity': 1.0,
#     'specificity': 0.0,
#     'precision': 0.1429,
#     'f1': 0.25,
#     'tp': 1,
#     'tn': 0,
#     'fp': 6,
#     'fn': 0,
#     'n': 7}},
#   'macro': {'macro_f1': 0.1274,
#    'macro_sensitivity': 0.4286,
#    'macro_specificity': 0.0,
#    'macro_precision': 0.0795}}}

# %%
import pandas as pd
traces = pd.read_json('evals/results/baseline_qwen35_08b.traces.jsonl', lines=True)

# %%
traces
# Out:
#     uid                                      frontal_image  gt_normal  \
# 0    29  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 1    33  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 2    74                                               None      False
# 3    46  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 4    55  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 5    21  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 6     4  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 7     9  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 8    98  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 9    37  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 10   58  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 11   56  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 12  141  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 13   78  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 14   66  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 15  138  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 16  181  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 17  229  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 18  120  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 19   57  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 20  173  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 21  102  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 22  106  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 23  152  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 24  159  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 25  107  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 26  192  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 27  226  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 28  201  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 29  183  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 30  235                                               None      False
# 31  143  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 32  171  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 33  251  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
# 34  291  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 35  222  /raid/manoj/smallvlm/raddar/chest-xrays-indian...       True
# 36  253  /raid/manoj/smallvlm/raddar/chest-xrays-indian...      False
#
#                                           gt_problems  l1_raw  l1_pred  \
# 0   [Cardiomegaly, Diaphragm, Tube, Inserted, Airs...  Normal      1.0
# 1                              [Surgical Instruments]  Normal      1.0
# 2   [Calcified Granuloma, Atherosclerosis, Kyphosi...              NaN
# 3                                                  []  Normal      1.0
# 4                                              [Lung]  Normal      1.0
# 5   [Calcified Granuloma, Breast Implants, Deformity]  Normal      1.0
# 6   [Pulmonary Disease, Chronic Obstructive, Bullo...  Normal      1.0
# 7                      [Calcified Granuloma, Density]  Normal      1.0
# 8                       [Lung, Pulmonary Atelectasis]  Normal      1.0
# 9                                           [Opacity]  Normal      1.0
# 10                    [Thoracic Vertebrae, Scoliosis]  Normal      1.0
# 11                                                 []  Normal      1.0
# 12                                                 []  Normal      1.0
# 13                            [Pulmonary Atelectasis]  Normal      1.0
# 14                                                 []  Normal      1.0
# 15                                                 []  Normal      1.0
# 16                        [Diaphragmatic Eventration]  Normal      1.0
# 17                               [Calcinosis, Nodule]  Normal      1.0
# 18               [Lung, Markings, Thoracic Vertebrae]  Normal      1.0
# 19                   [Tube, Inserted, Opacity, Spine]  Normal      1.0
# 20                                 [Lung, Calcinosis]  Normal      1.0
# 21                                    [Lung, Density]  Normal      1.0
# 22                                                 []  Normal      1.0
# 23  [Cardiomegaly, Aorta, Deformity, Fractures, Bone]  Normal      1.0
# 24                                       [Osteophyte]  Normal      1.0
# 25                                                 []  Normal      1.0
# 26                         [Lung, Thoracic Vertebrae]  Normal      1.0
# 27                                                 []  Normal      1.0
# 28  [Opacity, Aorta, Thoracic, Atherosclerosis, Th...  Normal      1.0
# 29  [Lung, Markings, Opacity, Spine, Airspace Dise...  Normal      1.0
# 30  [Implanted Medical Device, Cardiac Shadow, Opa...              NaN
# 31    [Granulomatous Disease, Calcinosis, Calcinosis]  Normal      1.0
# 32                                                 []  Normal      1.0
# 33                      [Lung, Granulomatous Disease]  Normal      1.0
# 34                                                 []  Normal      1.0
# 35                                                 []  Normal      1.0
# 36              [Pneumothorax, Catheters, Indwelling]  Normal      1.0
#
#                                                l2_raw  \
# 0   ```json\n[\n\t{"Finding Name": "Calcinosis", "...
# 1   ```json\n[\n    {"Finding Name": "Pleural Effu...
# 2
# 3   ```json\n[\n    {\n        "Finding Name": "Pl...
# 4   ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 5   ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 6   ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 7   ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 8   ```json\n[\n\t{"r": "Cardiomegaly", "f": true}...
# 9   ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 10  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 11  ```json\n[\n  {"Finding Name": "Pleural Effusi...
# 12  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 13  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 14  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 15  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 16  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 17  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 18  ```json\n[\n\t{"Finding Name": "Cardiomegaly",...
# 19  ```json\n[\n\t{"Finding Name": "Cardiomegaly",...
# 20  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 21  ```json\n[\n    {\n        "Finding Name": "Ca...
# 22  ```json\n[\n    {"Finding Name": "Pleural Effu...
# 23  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 24  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 25  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 26  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 27  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 28  ```json\n[\n  {\n    "Finding Name": "Cardiome...
# 29  ```json\n[\n    {\n        "Finding Name": "Ca...
# 30
# 31  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 32  ```json\n[\n    {\n        "Finding Name": "Pl...
# 33  ```json\n[\n    {"Finding Name": "Pleural Effu...
# 34  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 35  ```json\n[\n  {\n    "Finding Name": "Pleural ...
# 36  ```json\n[\n  {\n    "Finding Name": "Pleural ...
#
#                                               l2_pred  \
# 0   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 1   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 2   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 3   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 4   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 5   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 6   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 7   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 8   {'Cardiomegaly': True, 'Pleural Effusion': Tru...
# 9   {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 10  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 11  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 12  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 13  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 14  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 15  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 16  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 17  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 18  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 19  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 20  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 21  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 22  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 23  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 24  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 25  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 26  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 27  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 28  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 29  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 30  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 31  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 32  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 33  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 34  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 35  {'Cardiomegaly': None, 'Pleural Effusion': Non...
# 36  {'Cardiomegaly': None, 'Pleural Effusion': Non...
#
#                                                l3_raw  \
# 0   **Findings:**\nThe cardiac silhouette is enlar...
# 1   **Findings:** The heart size is normal with an...
# 2
# 3   **Findings:** The lungs are clear without foca...
# 4   **Findings:** The heart size is normal with an...
# 5   **Findings:** The heart size is normal with an...
# 6   **Findings:** The heart is normal size and con...
# 7   **Findings:** The heart size is normal with an...
# 8   **Findings:** The cardiac silhouette is normal...
# 9   **Findings:** The heart size is normal with an...
# 10  **Findings:** The cardiac silhouette is normal...
# 11  **Findings:** The lungs are clear without foca...
# 12  **Findings:** The heart size is normal with an...
# 13  **Findings:** The heart size is normal with an...
# 14  **Findings:** The lungs are clear without foca...
# 15  **Findings:** The lungs are clear without foca...
# 16  **Findings:** The heart size is normal with an...
# 17  **Findings:** The heart size is normal with an...
# 18  **Findings:**\nThe cardiac silhouette is enlar...
# 19  **Findings:** \nThe cardiac silhouette is enla...
# 20  **Findings:** The heart size is normal with an...
# 21  **Findings:** The heart size is normal with an...
# 22  **Findings:** The heart size is normal with an...
# 23  **Findings:** The cardiac silhouette is enlarg...
# 24  **Findings:** The cardiac silhouette is normal...
# 25  **Findings:** The lungs are clear without foca...
# 26  **Findings:** The heart size is normal, and th...
# 27  **Findings:** The lungs are clear and well-exp...
# 28  **Findings:** The cardiac silhouette is normal...
# 29  **Findings:** The heart size is normal, and th...
# 30
# 31  **Findings:** The heart size is normal with an...
# 32  **Findings:** The heart size is normal with an...
# 33  **Findings:** The heart size is normal with an...
# 34  **Findings:** The lungs are clear and well-exp...
# 35  **Findings:** The heart size is normal with an...
# 36  **Findings:** The lungs are clear and well-exp...
#
#                                           l3_findings  \
# 0   The cardiac silhouette is enlarged, but limits...
# 1   The heart size is normal with an estimated lef...
# 2
# 3   The lungs are clear without focal consolidatio...
# 4   The heart size is normal with an unremarkable ...
# 5   The heart size is normal with an unremarkable ...
# 6   The heart is normal size and contour with no c...
# 7   The heart size is normal with an unremarkable ...
# 8   The cardiac silhouette is normal size and cont...
# 9   The heart size is normal with an unremarkable ...
# 10  The cardiac silhouette is normal size and cont...
# 11  The lungs are clear without focal consolidatio...
# 12  The heart size is normal with an estimated lef...
# 13  The heart size is normal with an unremarkable ...
# 14  The lungs are clear without focal consolidatio...
# 15  The lungs are clear without focal consolidatio...
# 16  The heart size is normal with an unremarkable ...
# 17  The heart size is normal with an unremarkable ...
# 18  The cardiac silhouette is enlarged, but evalua...
# 19  The cardiac silhouette is enlarged, but limits...
# 20  The heart size is normal with an unremarkable ...
# 21  The heart size is normal with an estimated lef...
# 22  The heart size is normal with an unremarkable ...
# 23  The cardiac silhouette is enlarged, but not si...
# 24  The cardiac silhouette is normal size and cont...
# 25  The lungs are clear without focal consolidatio...
# 26  The heart size is normal, and there is no foca...
# 27  The lungs are clear and well-expanded without ...
# 28  The cardiac silhouette is normal size and cont...
# 29  The heart size is normal, and there is no pleu...
# 30
# 31  The heart size is normal with an unremarkable ...
# 32  The heart size is normal with an unremarkable ...
# 33  The heart size is normal with an unremarkable ...
# 34  The lungs are clear and well-expanded without ...
# 35  The heart size is normal with an unremarkable ...
# 36  The lungs are clear and well-expanded without ...
#
#                                         l3_impression
# 0   Persistent elevated left hemidiaphragm suggest...
# 1
# 2
# 3
# 4
# 5   Normal cardiopulmonary examination. Mild multi...
# 6
# 7
# 8   Mild bibasilar linear opacities likely represe...
# 9   Normal cardiomediastinal silhouette; lungs cle...
# 10  Normal heart size and mediastinum. Clear lungs...
# 11
# 12
# 13  Normal cardiomediastinum and lungs. Stable app...
# 14  Normal chest x-ray with no evidence of pneumon...
# 15
# 16
# 17
# 18  Low volume lungs despite adequate inspiration ...
# 19  Cardiomegaly (limited) + possible early conges...
# 20
# 21
# 22
# 23
# 24  Multiple bilateral older rib lesions suggestiv...
# 25
# 26  Low inspiratory effort suggests possible early...
# 27
# 28
# 29  Right lower lobe consolidation consistent with...
# 30
# 31  Normal cardiopulmonary examination. Mild degen...
# 32  Normal cardiopulmonary examination. No evidenc...
# 33  Normal cardiopulmonary examination including l...
# 34  Clear lungs bilaterally. Normal heart size. Hi...
# 35
# 36

# %%
trace = traces['l3_raw'].tolist()

# %%
from pprint import pprint

# %%
pprint(trace[10])
# Out:
# ('**Findings:** The cardiac silhouette is normal size and contour. Mediastinal '
#  'contours, hilar structures, and pleural surfaces appear unremarkable without '
#  'evidence of acute disease or abnormality. Lungs are clear bilaterally with '
#  'no focal consolidation, pneumothorax, pulmonary edema, or interstitial '
#  'markings suggestive of pneumonia; however, there may be mild bibasilar '
#  'atelectasis noted. Osseous abnormalities include metallic hardware '
#  'consistent with prior cervical spine fusion surgery visible along the lower '
#  'thoracic vertebral column. No other osseous pathology identified. Clinical '
#  "correlation recommended given patient's history regarding recent trauma to "
#  'left shoulder (implied by "KAB" marker). \n'
#  '\n'
#  '---\n'
#  '\n'
#  '**Impression:** Normal heart size and mediastinum. Clear lungs except '
#  'possibly minimal basal atelectysis. Metallic surgical clips from previous '
#  'spinal fixation present. Left shoulder injury likely related to minor trauma '
#  'not fully assessed here—clinical evaluation required.')
